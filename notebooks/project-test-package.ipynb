# %% [markdown]
# ### Import libs from packages

# %%
import pandas as pd
from nlp.engineer.processors.rawing.raw_processor import Rawing
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Configure coluns to anonymizer

# %%
recipe = {
  "rawing": {
    "path": "home/eneasj/Downloads",
    "unique_identifier_columns": [
      "id_unico"
    ],
    "anonymizer": {
      "steps": {
        "remove_names": {
          "columns": [
            "text"
          ],
          "most_frequent": 4000,
          "extra_names": [],
          "client_name_column": ""
        },
        "remove_personal_document": {
          "columns": [
            "text"
          ]
        },
        "remove_telephone_number": {
          "columns": [
            "text"
          ]
        },
        "remove_address_info": {
          "columns": [
            "text"
          ]
        },
        "remove_car_info": {
          "columns": [
            "text"
          ]
        }
      }
    },
    "export": {
      "columns": [
        "id_unico",
        "file",
        "prob_1",
        "time_speaker",
        "locutor",
        "text",
        "P_DATE",
        "time_speaker_hour",
        "interlocutor",
        "date_time",
        "message_order"
      ]
    }
  }
}

# %% [markdown]
# ### Creating DataFrame

# %%
dados = {'indices_id': ['0','1','2','3'],
         'Frase original': ['Olhando para a escala na parede eneas, qual valor indicaria melhor a sua dor hoje? rodrigues',
                           'Olhando para a escala na parede joão pedro, qual valor indicaria melhor a sua dor hoje? pedrinho',
                           'Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?',
                           'Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?'],
         'Frases comparativas': ['De acordo com a escala de dor ali na parede', 
                                'qual valor você acha que mais representa a sua dor?',
                                'De 0 a 10, qual o nível de intensidade da sua dor atualmente?',
                                'Qual a intensidade da sua dor?'],
         }

# %%
dataset = pd.DataFrame(dados)

# %%
dataset
# Out:
#   indices_id  \
# 0          0
# 1          1
# 2          2
# 3          3
#
#                                                                  Frase original  \
# 0  Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?
# 1  Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?
# 2  Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?
# 3  Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?
#
#                                              Frases comparativas
# 0                    De acordo com a escala de dor ali na parede
# 1            qual valor você acha que mais representa a sua dor?
# 2  De 0 a 10, qual o nível de intensidade da sua dor atualmente?
# 3                                 Qual a intensidade da sua dor?

# %%
dataset.shape
# Out:
# (4, 3)

# %% [markdown]
# ### Building Process

# %%
dataframe = Rawing.call_process(df=dataset,recipe=recipe)
# Out:
# Exception ignored on calling ctypes callback function: <function _ThreadpoolInfo._find_modules_with_dl_iterate_phdr.<locals>.match_module_callback at 0x7fd592cfed30>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.8/site-packages/threadpoolctl.py", line 400, in match_module_callback
#     self._make_module_from_path(filepath)
#   File "/opt/conda/lib/python3.8/site-packages/threadpoolctl.py", line 515, in _make_module_from_path
#     module = module_class(filepath, prefix, user_api, internal_api)
#   File "/opt/conda/lib/python3.8/site-packages/threadpoolctl.py", line 606, in __init__
#     self.version = self.get_version()
#   File "/opt/conda/lib/python3.8/site-packages/threadpoolctl.py", line 646, in get_version
#     config = get_config().split()
# AttributeError: 'NoneType' object has no attribute 'split'
# [03/13 10:12:41] - [Info]:  Start Process to Similary Words
# [03/13 10:12:41] - [Info]:  Load DataFrame
# [03/13 10:12:41] - [Info]:  load csf file
# [03/13 10:12:41] - [Info]:  Finishing Process
# [03/13 10:12:41] - [Debug]:  Numbers of columns and Rows (4, 3)
# [03/13 10:12:41] - [Debug]:  Columns Name Index(['indices_id', 'Frase original', 'Frases comparativas'], dtype='object')
# [03/13 10:12:41] - [Info]:  Start Process to Transform Data
# [03/13 10:12:41] - [Debug]:  column created:
#  0    olhando escala parede valor indicaria melhor dor hoje
# 1    olhando escala parede valor indicaria melhor dor hoje
# 2    olhando escala parede valor indicaria melhor dor hoje
# 3    olhando escala parede valor indicaria melhor dor hoje
# Name: Frase original_clean, dtype: object
# [03/13 10:12:41] - [Debug]:  column created:
#  0        acordo escala dor ali parede
# 1      valor voce acha representa dor
# 2    nivel intensidade dor atualmente
# 3                     intensidade dor
# Name: Frases comparativas_clean, dtype: object
# [03/13 10:12:41] - [Info]:  Convert Text to Tokens
# [03/13 10:12:41] - [Debug]:  column created:
#  0    [olhando, escala, parede, valor, indicaria, melhor, dor, hoje]
# 1    [olhando, escala, parede, valor, indicaria, melhor, dor, hoje]
# 2    [olhando, escala, parede, valor, indicaria, melhor, dor, hoje]
# 3    [olhando, escala, parede, valor, indicaria, melhor, dor, hoje]
# Name: Frase original_token, dtype: object
# [03/13 10:12:41] - [Debug]:  column created:
#  0       [acordo, escala, dor, ali, parede]
# 1     [valor, voce, acha, representa, dor]
# 2    [nivel, intensidade, dor, atualmente]
# 3                       [intensidade, dor]
# Name: Frases comparativas_token, dtype: object
# [03/13 10:12:41] - [Debug]:  concat two columns from text ['Frase original', 'Frases comparativas']
# [03/13 10:12:41] - [Debug]:  consolideted column:
#  0       [olhando, escala, parede, valor, indicaria, melhor, dor, hoje, acordo, escala, dor, ali, parede]
# 1     [olhando, escala, parede, valor, indicaria, melhor, dor, hoje, valor, voce, acha, representa, dor]
# 2    [olhando, escala, parede, valor, indicaria, melhor, dor, hoje, nivel, intensidade, dor, atualmente]
# 3                       [olhando, escala, parede, valor, indicaria, melhor, dor, hoje, intensidade, dor]
# Name: concatenado, dtype: object
# [03/13 10:12:41] - [Info]:  Extract Features from Similar Words
# [03/13 10:12:41] - [Debug]:  Visualize Vocabulary Similars
#  ['olhando', 'escala', 'parede', 'valor', 'indicaria', 'melhor', 'dor', 'hoje', 'acordo', 'ali', 'voce', 'acha', 'representa', 'nivel', 'intensidade', 'atualmente']
# [03/13 10:12:41] - [Info]:  List of silimar Words
# [03/13 10:12:41] - [Debug]:  list of specific words
#  <bound method BaseWordEmbeddingsModel.most_similar of <gensim.models.word2vec.Word2Vec object at 0x7fd592d1c280>>
# [03/13 10:12:41] - [Info]:  Word selected: dor List of search specific similar words: [('nivel', 0.21), ('representa', 0.21), ('olhando', 0.09), ('intensidade', 0.09), ('hoje', 0.08), ('ali', 0.04), ('voce', 0.03), ('parede', 0.01), ('indicaria', -0.03), ('valor', -0.03)]
# [03/13 10:12:41] - [Info]:  Word Embedding
# [03/13 10:12:42] - [Debug]:  Word Embedding Results:
#  [[[-1210.9719     -493.62204  ]
#   [ -689.4607    -1107.7719   ]
#   [ -469.9657    -2402.981    ]
#   [-1491.7496     2429.6853   ]
#   [ -213.13878     276.24152  ]
#   [ 1272.4763     2064.4458   ]
#   [  615.5053     -815.94714  ]
#   [  945.18097      69.66312  ]
#   [-1456.0834    -1287.5819   ]
#   [ -341.7778     2350.229    ]
#   [ -702.81134     781.0488   ]
#   [  467.05176     832.2197   ]
#   [ 2252.8062     -774.70404  ]
#   [ 2283.0374      906.24475  ]
#   [ 1092.967     -2180.4226   ]]
#
#  [[ 2252.8062     -774.70404  ]
#   [ -469.9657    -2402.981    ]
#   [ 2283.0374      906.24475  ]
#   [  946.1874     -982.2333   ]
#   [ 1272.4763     2064.4458   ]
#   [ 1272.4253      241.26482  ]
#   [-2012.112      1385.5176   ]
#   [  412.19678    1197.287    ]
#   [ -341.7778     2350.229    ]
#   [ -325.983     -1186.9069   ]
#   [-1210.8352     -121.46958  ]
#   [ -843.95184    1123.6519   ]
#   [-2438.8167      -57.705097 ]
#   [    3.4075234   -23.742146 ]
#   [-1778.3047    -1475.6072   ]]
#
#  [[-2012.112      1385.5176   ]
#   [ 1092.967     -2180.4226   ]
#   [-2438.8167      -57.705097 ]
#   [  946.1874     -982.2333   ]
#   [ 1272.4763     2064.4458   ]
#   [ -843.95184    1123.6519   ]
#   [-1210.8352     -121.46958  ]
#   [ -325.983     -1186.9069   ]
#   [ 2252.8062     -774.70404  ]
#   [-1778.3047    -1475.6072   ]
#   [    3.4075234   -23.742146 ]
#   [ -341.7778     2350.229    ]
#   [ 2283.0374      906.24475  ]
#   [  412.19678    1197.287    ]
#   [ 1272.4253      241.26482  ]]
#
#  [[ 2283.0374      906.24475  ]
#   [-1210.8352     -121.46958  ]
#   [-2012.112      1385.5176   ]
#   [  412.19678    1197.287    ]
#   [ -469.9657    -2402.981    ]
#   [ 2252.8062     -774.70404  ]
#   [    3.4075234   -23.742146 ]
#   [-2438.8167      -57.705097 ]
#   [ 1092.967     -2180.4226   ]
#   [ -341.7778     2350.229    ]
#   [-1778.3047    -1475.6072   ]
#   [ -325.983     -1186.9069   ]
#   [ -843.95184    1123.6519   ]
#   [ 1272.4253      241.26482  ]
#   [ 1272.4763     2064.4458   ]]
#
#  [[ -341.7778     2350.229    ]
#   [    3.4075234   -23.742146 ]
#   [-2012.112      1385.5176   ]
#   [  946.1874     -982.2333   ]
#   [ 1272.4253      241.26482  ]
#   [ -843.95184    1123.6519   ]
#   [ -325.983     -1186.9069   ]
#   [-1210.8352     -121.46958  ]
#   [ 1092.967     -2180.4226   ]
#   [ 2252.8062     -774.70404  ]
#   [-2438.8167      -57.705097 ]
#   [ 1272.4763     2064.4458   ]
#   [ 2283.0374      906.24475  ]
#   [ -469.9657    -2402.981    ]
#   [-1778.3047    -1475.6072   ]]
#
#  [[ -341.7778     2350.229    ]
#   [  412.19678    1197.287    ]
#   [ 1272.4763     2064.4458   ]
#   [-2438.8167      -57.705097 ]
#   [-1210.8352     -121.46958  ]
#   [ 1092.967     -2180.4226   ]
#   [ -843.95184    1123.6519   ]
#   [ 2252.8062     -774.70404  ]
#   [ -325.983     -1186.9069   ]
#   [  946.1874     -982.2333   ]
#   [-1778.3047    -1475.6072   ]
#   [ 2283.0374      906.24475  ]
#   [-2012.112      1385.5176   ]
#   [    3.4075234   -23.742146 ]
#   [ -469.9657    -2402.981    ]]
#
#  [[-2012.112      1385.5176   ]
#   [    3.4075234   -23.742146 ]
#   [-2438.8167      -57.705097 ]
#   [-1778.3047    -1475.6072   ]
#   [-1210.8352     -121.46958  ]
#   [ 1272.4763     2064.4458   ]
#   [ -843.95184    1123.6519   ]
#   [ -469.9657    -2402.981    ]
#   [  412.19678    1197.287    ]
#   [  946.1874     -982.2333   ]
#   [ 1272.4253      241.26482  ]
#   [ -341.7778     2350.229    ]
#   [ 1092.967     -2180.4226   ]
#   [ 2283.0374      906.24475  ]
#   [ 2252.8062     -774.70404  ]]
#
#  [[-2438.8167      -57.705097 ]
#   [  946.1874     -982.2333   ]
#   [ -325.983     -1186.9069   ]
#   [    3.4075234   -23.742146 ]
#   [ -843.95184    1123.6519   ]
#   [ -469.9657    -2402.981    ]
#   [ 1272.4253      241.26482  ]
#   [  412.19678    1197.287    ]
#   [-1778.3047    -1475.6072   ]
#   [ 2283.0374      906.24475  ]
#   [-2012.112      1385.5176   ]
#   [ 1272.4763     2064.4458   ]
#   [ 2252.8062     -774.70404  ]
#   [ 1092.967     -2180.4226   ]
#   [ -341.7778     2350.229    ]]
#
#  [[  946.1874     -982.2333   ]
#   [ 1272.4763     2064.4458   ]
#   [ 1092.967     -2180.4226   ]
#   [ 2252.8062     -774.70404  ]
#   [ -843.95184    1123.6519   ]
#   [ -341.7778     2350.229    ]
#   [-1778.3047    -1475.6072   ]
#   [ -325.983     -1186.9069   ]
#   [-1210.8352     -121.46958  ]
#   [  412.19678    1197.287    ]
#   [ -469.9657    -2402.981    ]
#   [    3.4075234   -23.742146 ]
#   [ 1272.4253      241.26482  ]
#   [-2438.8167      -57.705097 ]
#   [-2012.112      1385.5176   ]]
#
#  [[-2012.112      1385.5176   ]
#   [ 2283.0374      906.24475  ]
#   [ -469.9657    -2402.981    ]
#   [-2438.8167      -57.705097 ]
#   [ -325.983     -1186.9069   ]
#   [ 1272.4253      241.26482  ]
#   [ 1092.967     -2180.4226   ]
#   [ -341.7778     2350.229    ]
#   [  412.19678    1197.287    ]
#   [ -843.95184    1123.6519   ]
#   [    3.4075234   -23.742146 ]
#   [ 2252.8062     -774.70404  ]
#   [-1210.8352     -121.46958  ]
#   [  946.1874     -982.2333   ]
#   [-1778.3047    -1475.6072   ]]
#
#  [[-1210.8352     -121.46958  ]
#   [ -469.9657    -2402.981    ]
#   [ 2283.0374      906.24475  ]
#   [  412.19678    1197.287    ]
#   [ -325.983     -1186.9069   ]
#   [ 1272.4253      241.26482  ]
#   [    3.4075234   -23.742146 ]
#   [ 2252.8062     -774.70404  ]
#   [ -341.7778     2350.229    ]
#   [  946.1874     -982.2333   ]
#   [-2012.112      1385.5176   ]
#   [-2438.8167      -57.705097 ]
#   [-1778.3047    -1475.6072   ]
#   [ 1272.4763     2064.4458   ]
#   [ 1092.967     -2180.4226   ]]
#
#  [[ 1092.967     -2180.4226   ]
#   [ 2283.0374      906.24475  ]
#   [  946.1874     -982.2333   ]
#   [    3.4075234   -23.742146 ]
#   [ -469.9657    -2402.981    ]
#   [ -843.95184    1123.6519   ]
#   [ 1272.4253      241.26482  ]
#   [  412.19678    1197.287    ]
#   [ -341.7778     2350.229    ]
#   [ 1272.4763     2064.4458   ]
#   [-1210.8352     -121.46958  ]
#   [-1778.3047    -1475.6072   ]
#   [-2438.8167      -57.705097 ]
#   [ -325.983     -1186.9069   ]
#   [-2012.112      1385.5176   ]]
#
#  [[ -325.983     -1186.9069   ]
#   [-1778.3047    -1475.6072   ]
#   [  412.19678    1197.287    ]
#   [-1210.8352     -121.46958  ]
#   [ -341.7778     2350.229    ]
#   [-2438.8167      -57.705097 ]
#   [-2012.112      1385.5176   ]
#   [  946.1874     -982.2333   ]
#   [ 2252.8062     -774.70404  ]
#   [ -843.95184    1123.6519   ]
#   [ -469.9657    -2402.981    ]
#   [ 1272.4763     2064.4458   ]
#   [ 2283.0374      906.24475  ]
#   [ 1272.4253      241.26482  ]
#   [ 1092.967     -2180.4226   ]]
#
#  [[ -469.9657    -2402.981    ]
#   [ -325.983     -1186.9069   ]
#   [ 1272.4763     2064.4458   ]
#   [  946.1874     -982.2333   ]
#   [  412.19678    1197.287    ]
#   [ -341.7778     2350.229    ]
#   [-2438.8167      -57.705097 ]
#   [    3.4075234   -23.742146 ]
#   [-1778.3047    -1475.6072   ]
#   [ 1092.967     -2180.4226   ]
#   [ -843.95184    1123.6519   ]
#   [-1210.8352     -121.46958  ]
#   [ 1272.4253      241.26482  ]
#   [ 2283.0374      906.24475  ]
#   [ 2252.8062     -774.70404  ]]
#
#  [[    3.4075234   -23.742146 ]
#   [ -325.983     -1186.9069   ]
#   [-2012.112      1385.5176   ]
#   [  946.1874     -982.2333   ]
#   [ -341.7778     2350.229    ]
#   [-2438.8167      -57.705097 ]
#   [ -469.9657    -2402.981    ]
#   [ 2283.0374      906.24475  ]
#   [ -843.95184    1123.6519   ]
#   [-1210.8352     -121.46958  ]
#   [ 1272.4763     2064.4458   ]
#   [ 2252.8062     -774.70404  ]
#   [ 1272.4253      241.26482  ]
#   [  412.19678    1197.287    ]
#   [ 1092.967     -2180.4226   ]]
#
#  [[  412.19678    1197.287    ]
#   [ 1272.4253      241.26482  ]
#   [-2012.112      1385.5176   ]
#   [    3.4075234   -23.742146 ]
#   [ 2283.0374      906.24475  ]
#   [ 1272.4763     2064.4458   ]
#   [  946.1874     -982.2333   ]
#   [-1778.3047    -1475.6072   ]
#   [ -843.95184    1123.6519   ]
#   [-2438.8167      -57.705097 ]
#   [ -325.983     -1186.9069   ]
#   [ 1092.967     -2180.4226   ]
#   [ -469.9657    -2402.981    ]
#   [ 2252.8062     -774.70404  ]
#   [-1210.8352     -121.46958  ]]]
# [03/13 10:12:42] - [Info]:  Loaded {'hoje', 'olhando', 'acha', 'representa', 'atualmente', 'indicaria', 'voce', 'acordo', 'intensidade', 'escala', 'melhor', 'parede', 'valor', 'nivel', 'dor', 'ali'} words in vocabulary 16
# [03/13 10:12:42] - [Debug]:  build matrix with similar words
# [03/13 10:12:42] - [Debug]:  matrix of similars: n\ ['olhando', 'escala', 'parede', 'valor', 'indicaria', 'melhor', 'dor', 'hoje', 'acordo', 'ali', 'voce', 'acha', 'representa', 'nivel', 'intensidade', 'atualmente']
# [03/13 10:12:42] - [Info]:  Score a target sentence to source sentences
# [03/13 10:12:42] - [Info]:  Target: ['Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?', 'De acordo com a escala de dor ali na parede', 'qual valor você acha que mais representa a sua dor?', 'De 0 a 10, qual o nível de intensidade da sua dor atualmente?', 'Qual a intensidade da sua dor?']
# [03/13 10:12:42] - [Info]:  [(0.5025379657745361, 'indicaria'), (0.4746072292327881, 'valor'), (0.4410971403121948, 'escala'), (0.41695713996887207, 'melhor'), (0.37047669291496277, 'dor'), (0.12125526368618011, 'nivel'), (0.10627702623605728, 'atualmente'), (0.04095456004142761, 'hoje'), (0.01484091579914093, 'representa'), (-0.02397688664495945, 'acordo'), (-0.0316120907664299, 'acha'), (-0.03861050307750702, 'olhando'), (-0.0400129072368145, 'voce'), (-0.047794755548238754, 'ali'), (-0.09289667755365372, 'parede'), (-0.17683571577072144, 'intensidade')]
# [03/13 10:12:42] - [Info]:  Target: ['Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?', 'De acordo com a escala de dor ali na parede', 'qual valor você acha que mais representa a sua dor?', 'De 0 a 10, qual o nível de intensidade da sua dor atualmente?', 'Qual a intensidade da sua dor?']
# [03/13 10:12:42] - [Info]:  [(0.5561935901641846, 'ali'), (0.49527546763420105, 'escala'), (0.46165409684181213, 'acordo'), (0.4451654851436615, 'parede'), (0.3738775849342346, 'dor'), (0.16338782012462616, 'nivel'), (0.04690225049853325, 'valor'), (-0.031071379780769348, 'voce'), (-0.031964801251888275, 'acha'), (-0.05443479120731354, 'atualmente'), (-0.05682075023651123, 'olhando'), (-0.07938997447490692, 'hoje'), (-0.08261338621377945, 'representa'), (-0.11860720068216324, 'intensidade'), (-0.15215465426445007, 'indicaria'), (-0.16414843499660492, 'melhor')]
# [03/13 10:12:42] - [Info]:  Target: ['Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?', 'De acordo com a escala de dor ali na parede', 'qual valor você acha que mais representa a sua dor?', 'De 0 a 10, qual o nível de intensidade da sua dor atualmente?', 'Qual a intensidade da sua dor?']
# [03/13 10:12:42] - [Info]:  [(0.6215079426765442, 'valor'), (0.617608904838562, 'acha'), (0.5387046337127686, 'representa'), (0.08726560324430466, 'indicaria'), (0.07327303290367126, 'acordo'), (0.05547956004738808, 'hoje'), (0.0510965958237648, 'escala'), (0.008434401825070381, 'parede'), (0.0015646585961803794, 'intensidade'), (-0.029188869521021843, 'atualmente'), (-0.04607221484184265, 'voce'), (-0.04724181070923805, 'olhando'), (-0.058898307383060455, 'dor'), (-0.09588749706745148, 'nivel'), (-0.14680837094783783, 'melhor'), (-0.1519709974527359, 'ali')]
# [03/13 10:12:42] - [Info]:  Target: ['Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?', 'De acordo com a escala de dor ali na parede', 'qual valor você acha que mais representa a sua dor?', 'De 0 a 10, qual o nível de intensidade da sua dor atualmente?', 'Qual a intensidade da sua dor?']
# [03/13 10:12:42] - [Info]:  [(0.7521964311599731, 'intensidade'), (0.7219634056091309, 'dor'), (0.2438831329345703, 'representa'), (0.13650032877922058, 'nivel'), (0.046441301703453064, 'olhando'), (0.005806516390293837, 'hoje'), (-0.012921147048473358, 'parede'), (-0.02249363251030445, 'voce'), (-0.02489611692726612, 'valor'), (-0.04193400964140892, 'atualmente'), (-0.05816993862390518, 'ali'), (-0.07106807827949524, 'acordo'), (-0.11775674670934677, 'melhor'), (-0.12520262598991394, 'indicaria'), (-0.1647345870733261, 'escala'), (-0.253398597240448, 'acha')]
# [03/13 10:12:42] - [Info]:  Target: ['Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?', 'De acordo com a escala de dor ali na parede', 'qual valor você acha que mais representa a sua dor?', 'De 0 a 10, qual o nível de intensidade da sua dor atualmente?', 'Qual a intensidade da sua dor?']
# [03/13 10:12:42] - [Info]:  [(1.0, 'intensidade'), (0.1513470709323883, 'representa'), (0.08711781352758408, 'dor'), (-0.005629649851471186, 'nivel'), (-0.007715226151049137, 'valor'), (-0.0114787258207798, 'atualmente'), (-0.017531370744109154, 'olhando'), (-0.02617919072508812, 'parede'), (-0.0270426906645298, 'acordo'), (-0.06083327531814575, 'voce'), (-0.07247790694236755, 'hoje'), (-0.11760875582695007, 'ali'), (-0.12223295867443085, 'acha'), (-0.12677261233329773, 'melhor'), (-0.1562366783618927, 'indicaria'), (-0.1831527203321457, 'escala')]
# [03/13 10:12:42] - [Debug]:  target phrases: ['Olhando para a escala na parede, qual valor indicaria melhor a sua dor hoje?', 'De acordo com a escala de dor ali na parede', 'qual valor você acha que mais representa a sua dor?', 'De 0 a 10, qual o nível de intensidade da sua dor atualmente?', 'Qual a intensidade da sua dor?']
# [03/13 10:12:42] - [Debug]:  build relationship words positive e negative correlation
# [03/13 10:12:42] - [Debug]:  relationship words:
#  [('acha', 0.1848650723695755), ('escala', 0.1454274207353592), ('ali', 0.12736645340919495), ('atualmente', 0.10118116438388824), ('indicaria', 0.07927341759204865), ('valor', 0.06797412037849426), ('voce', 0.03650302439928055), ('hoje', -0.04019467532634735), ('olhando', -0.09721773862838745), ('parede', -0.159801185131073)]
# [03/13 10:12:42] - [Info]:  Finishing Process
